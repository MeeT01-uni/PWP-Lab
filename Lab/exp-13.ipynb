# %%
file1 = open(r"../Lab/lab-13-materials/ict.txt")
file1
# Out:
# <_io.TextIOWrapper name='../Lab/lab-13-materials/ict.txt' mode='r' encoding='cp1252'>

# %%
f1 = open(r"../Lab/lab-13-materials/ict.txt")
# This will print every line one by one in the file
for each in f1:
    print (each)
# Out:
# ICT ICT ICT
#
# ICT ICT ICT ICT ICT

# %%
# Python code to illustrate read() mode
f1 = open(r"../Lab/lab-13-materials/ict.txt")
print (f1.read())
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
with open(r"../Lab/lab-13-materials/ict.txt",'r') as f1:  
    data = f1.read() 
print(data)
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
f1 = open(r"../Lab/lab-13-materials/ict.txt")
print (f1.read(5))
# Out:
# ICT I

# %%
with open(r"../Lab/lab-13-materials/ict.txt",'r') as file:
    data = file.readlines()
    for line in data:
        word = line.split()
        print (word)
# Out:
# ['ICT', 'ICT', 'ICT']
# ['ICT', 'ICT', 'ICT', 'ICT', 'ICT']

# %%
file = open("../Lab/lab-13-materials/ict.txt",'w')
file.write("ICT ICT ICT \n")
file.write("ICT ICT ICT ICT ICT")
file.close()
file = open("../Lab/lab-13-materials/ict.txt",'r')
print(file.read())
# Out:
# ICT ICT ICT
# ICT ICT ICT ICT ICT

# %%
with open("../Lab/lab-13-materials/ict.txt", "w") as f: 
    f.write("Hello World!!!") 
    f.close()

# %%
file = open("../Lab/lab-13-materials/ict.txt",'a')
file.write("\n Department Department")
file.close()

# %%
with open(r'../Lab/lab-13-materials/a.tif', 'rb') as file:
    binary_data = file.read()
binary_data
# Out:
# b'MM\x00*\x00\x00\xfdh\x0b\x9c\x9f\x9e\x9b\x9e\x9c\x9f\x9e\x9d\x9e\x9e\x9f\xfe\xa08!\x
# ...

# %%
with open('../Lab/lab-13-materials/a.tif', 'wb') as f:
    f.write(binary_data)
    f.close()

# %%
import csv
with open('../Lab/lab-13-materials/data-1.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['sr ', 'M']
# ['1', 'a']
# ['2', 'b']
# ['3', 'c']

# %%
import csv
with open('../Lab/lab-13-materials/output.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Subject', 'Mark'])
    writer.writerow(['Aansh', 'PWP', 9])
    writer.writerow(['Ashutosh', 'PWP', 10])
    file.close()

# %%
# a.Write a program that reads a text file example.txt and counts the number of lines, words, and characters in the file. Print these counts.
file = open("../Lab/lab-13-materials/ict.txt",'r')
lines = file.readlines()
line_count = len(lines)
word_count = 0
char_count = 0
for line in lines:
    words = line.split()
    word_count += len(words)
    char_count += len(line)
print(f"Lines: {line_count}, Words: {word_count}, Characters: {char_count}")
file.close()
# Out:
# Lines: 2, Words: 4, Characters: 37

# %%
# b.Write a Python program to read a text file line by line and store each line in a list. Print the list after reading the entire file.
file = open("../Lab/lab-13-materials/ict.txt",'r')
lines = file.readlines()
line_list = []
for line in lines:
    line_list.append(line.strip())
print(line_list)
file.close()
# Out:
# ['Hello World!!!', 'Department Department']

# %%
# c.Write a Python program to read data from a CSV file data.csv and print each row to the console. 
import csv
with open('../Lab/lab-13-materials/data-1.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['sr ', 'M']
# ['1', 'a']
# ['2', 'b']
# ['3', 'c']

# %%
# Write a Python program that merges the contents of two text files file1.txt and file2.txt into a third file merged.txt. Ensure that the contents of file1.txt come first.
file1 = open("../Lab/lab-13-materials/ict.txt", 'r')
file2 = open("../Lab/lab-13-materials/ict.txt", 'r')
merged = open("../Lab/lab-13-materials/merged.txt", 'w')
merged.writelines(file1.readlines())
merged.writelines(file2.readlines())
file1.close()
file2.close()
merged.close()
